# %% [markdown]
# ### **Week 3**

# %% [markdown]
# **DATASET** <br>
# https://raw.githubusercontent.com/NathaliaMinoque/dataset/refs/heads/main/MBA.csv <br>
#
#
#
# **METADATA** <br>
# application_id: Unique identifier for each application <br>
# gender: Applicant's gender (Male, Female)<br>
# international: International student (TRUE/FALSE)<br>
# gpa: Grade Point Average of the applicant (on 4.0 scale)<br>
# major: Undergraduate major (Business, STEM, Humanities)<br>
# race: Racial background of the applicant (e.g., White, Black, Asian, Hispanic, Other / null: international student)<br>
# gmat: GMAT score of the applicant (800 points)<br>
# work_exp: Number of years of work experience (Year)<br>
# work_industry: Industry of the applicant's previous work experience (e.g., Consulting, Finance, Technology, etc.)<br>
# admission: Admission status (Admit, Waitlist, Null: Deny)<br>

# %%
#Import Library
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. display 5 columns from dataset

# %%
#1
data = pd.read_csv("https://raw.githubusercontent.com/NathaliaMinoque/dataset/refs/heads/main/MBA.csv")
data.head()
# Out:
#    application_id  gender  international   gpa       major      race   gmat  \
# 0               1  Female          False  3.30    Business     Asian  620.0
# 1               2    Male          False  3.28  Humanities     Black  680.0
# 2               3  Female           True  3.30    Business       NaN  710.0
# 3               4    Male          False  3.47        STEM     Black  690.0
# 4               5    Male          False  3.35        STEM  Hispanic  590.0
#
#    work_exp          work_industry admission
# 0       3.0     Financial Services     Admit
# 1       5.0  Investment Management       NaN
# 2       5.0             Technology     Admit
# 3       6.0             Technology       NaN
# 4       5.0             Consulting       NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['application_id'].plot(kind='hist', bins=20, title='application_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['gpa'].plot(kind='hist', bins=20, title='gpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['gmat'].plot(kind='hist', bins=20, title='gmat')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['work_exp'].plot(kind='hist', bins=20, title='work_exp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('international').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('major').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('race').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='application_id', y='gpa', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='gpa', y='gmat', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='gmat', y='work_exp', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['application_id']
#   ys = series['gpa']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('application_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('application_id')
# _ = plt.ylabel('gpa')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['application_id']
#   ys = series['gpa']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('application_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('international')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='international', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('application_id')
# _ = plt.ylabel('gpa')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['application_id']
#   ys = series['gpa']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('application_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('major')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='major', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('application_id')
# _ = plt.ylabel('gpa')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['application_id']
#   ys = series['gpa']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('application_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('race')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='race', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('application_id')
# _ = plt.ylabel('gpa')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['application_id'].plot(kind='line', figsize=(8, 4), title='application_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['gpa'].plot(kind='line', figsize=(8, 4), title='gpa')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['gmat'].plot(kind='line', figsize=(8, 4), title='gmat')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['work_exp'].plot(kind='line', figsize=(8, 4), title='work_exp')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['international'].value_counts()
#     for x_label, grp in _df_19.groupby('gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('gender')
# _ = plt.ylabel('international')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['major'].value_counts()
#     for x_label, grp in _df_20.groupby('international')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('international')
# _ = plt.ylabel('major')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['race'].value_counts()
#     for x_label, grp in _df_21.groupby('major')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('major')
# _ = plt.ylabel('race')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['work_industry'].value_counts()
#     for x_label, grp in _df_22.groupby('race')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('race')
# _ = plt.ylabel('work_industry')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='application_id', y='gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['international'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='application_id', y='international', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['major'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='application_id', y='major', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['race'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='application_id', y='race', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# 2. display the info column and conclude what the insight is from that column

# %%
#2
data.info()

#conclusion
# Dari data di bawah terdapat total 6194 entries, Namun untuk major hanya terdapat 4352 dan admission hanya memiliki 1000 entries. maka terdapat missing values.
# lalu juga ada 1 boolean, 3 float, 1 int, dan 5 object/string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6194 entries, 0 to 6193
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   application_id  6194 non-null   int64
#  1   gender          6194 non-null   object
#  2   international   6194 non-null   bool
#  3   gpa             6194 non-null   float64
#  4   major           6194 non-null   object
#  5   race            4352 non-null   object
#  6   gmat            6194 non-null   float64
#  7   work_exp        6194 non-null   float64
#  8   work_industry   6194 non-null   object
#  9   admission       1000 non-null   object
# dtypes: bool(1), float64(3), int64(1), object(5)
# memory usage: 441.7+ KB

# %% [markdown]
# 3. display the number of each unique value in the race and admission columns (including NaN)

# %%
#3a
admission = data['admission'].value_counts(dropna=False)
print(admission)
# Out:
# admission
# NaN         5194
# Admit        900
# Waitlist     100
# Name: count, dtype: int64

# %%
#3b
race_counts = data['race'].value_counts(dropna=False)
print(race_counts)
# Out:
# race
# NaN         1842
# White       1456
# Asian       1147
# Black        916
# Hispanic     596
# Other        237
# Name: count, dtype: int64

# %% [markdown]
# 4. fill NaN values in admission column to "deny" and null values in in race column to "other"

# %%
#4
data['admission'].fillna('Deny', inplace=True)
data['race'].fillna('Other', inplace=True)
# Out:
# <ipython-input-7-96364619aaa9>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['admission'].fillna('Deny', inplace=True)
# <ipython-input-7-96364619aaa9>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['race'].fillna('Other', inplace=True)

# %% [markdown]
# 5. recheck missing value

# %%
#5
data.isnull().sum()
# Out:
# application_id    0
# gender            0
# international     0
# gpa               0
# major             0
# race              0
# gmat              0
# work_exp          0
# work_industry     0
# admission         0
# dtype: int64

# %% [markdown]
# 6. drop application_id column

# %%
# 6
data.drop('application_id', axis=1, inplace=True)

# %% [markdown]
# 7. show describe column and conclude what the insight is from that column

# %%
#7
data.describe()
#conclusion
# gpa, gmat, work_exp memiliki 6194 data. rata-rata dari gpa 3.2, gmat 651, work_exp 5. data paling kecil dari gpa 2.65, gmat 570, work_exp 1.
# data paling besar dari gpa 3.77, gmat 780, work_exp 9
# Out:
#                gpa         gmat     work_exp
# count  6194.000000  6194.000000  6194.000000
# mean      3.250714   651.092993     5.016952
# std       0.151541    49.294883     1.032432
# min       2.650000   570.000000     1.000000
# 25%       3.150000   610.000000     4.000000
# 50%       3.250000   650.000000     5.000000
# 75%       3.350000   680.000000     6.000000
# max       3.770000   780.000000     9.000000

# %% [markdown]
# 8. make a visualization to analyze admission status based on major and explain the conclusions

# %%
#8
count_type_by_quality = data.groupby(['major',
'admission'])['admission'].count().unstack()
count_type_by_quality.plot (kind='barh',
figsize=(10,6))
plt.title('Admission Status by Major')
plt.xlabel('Number of Applicants')
plt.ylabel('Major')
plt.legend(title='Admission Status')

# Conslusion
# Humanities menjadi major yang paling banyak di deny namun juga major yang paling banyak di admit. Deny yang paling sedikit pada major Businesss.

# %% [markdown]
# 9. make a visualization to analyze the admissions in each major based on gender and explain the conclusions

# %%
#9
admitted_df = data[data['admission'] == 'Admit']
count_major_by_gender = admitted_df.groupby(['major',
'gender']) ['gender'].count().unstack()
count_major_by_gender.plot (kind='barh', figsize=(10,6))
plt.title( 'Admitted Applicants by Major and Gender')
plt.xlabel('Number of Admitted Applicants')
plt.ylabel( 'Major')
plt.legend(title= ' Gender')
plt.show()

# Gender Male terbanyak berasal dari Major Humanities sedangkan Gender female terbanyak berasal dari Major Humanities juga.
# Namun Untuk STEM Dan Business Male menjadi jurusan terbanyak dengan pendaftar yang ter terima dengan Gender Male.

# %% [markdown]
# 10. create your own insightful visualization and explain it in at least 2 sentences

# %%
#10
pie = data.groupby("gender")["gender"].count()
pie.plot(kind='pie', autopct='%1.2f%%',
title='Percentage of Gender Applicants')
plt.show()

# Berdasarkan total banyaknya pendaftar, pria menjadi pendaftar terbanyak sebanyak 63.66% dan wanita 36.34%.
# dari banyaknya total pendaftar 6194.

# %% [markdown]
# 11. create your own insightful visualization and explain it in at least 2 sentences

# %%
#11
pie = data.groupby("major")["major"].count()
pie.plot(kind='pie', autopct='%1.2f%%',
title='Percentage of Major Applicant')
plt.show()

# Humanities menjadi major terbanyak sejumlah 40.05% pendaftar sedangkan Business paling sedikit pendaftar sebanyak 29.67%.
# STEM hanya memiliki 30.27% pendaftar dari 6194.

# %% [markdown]
# 12. encode categorical columns and display the results

# %%
#12a
#encode X
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['gender'] = label_encoder.fit_transform(data['gender'])
data['international'] = label_encoder.fit_transform(data['international'])
data['major'] = label_encoder.fit_transform(data['major'])
data['race'] = label_encoder.fit_transform(data['race'])
data['work_industry'] = label_encoder.fit_transform(data['work_industry'])

data.head()
# Out:
#    gender  international   gpa  major  race   gmat  work_exp  work_industry  \
# 0       0              0  3.30      0     0  620.0       3.0              3
# 1       1              0  3.28      1     1  680.0       5.0              6
# 2       0              1  3.30      0     3  710.0       5.0             13
# 3       1              0  3.47      2     1  690.0       6.0             13
# 4       1              0  3.35      2     2  590.0       5.0              1
#
#   admission
# 0     Admit
# 1      Deny
# 2     Admit
# 3      Deny
# 4      Deny

# %%
#12b
#encode y
data['admission'] = label_encoder.fit_transform(data['admission'])
data.head()
# Out:
#    gender  international   gpa  major  race   gmat  work_exp  work_industry  \
# 0       0              0  3.30      0     0  620.0       3.0              3
# 1       1              0  3.28      1     1  680.0       5.0              6
# 2       0              1  3.30      0     3  710.0       5.0             13
# 3       1              0  3.47      2     1  690.0       6.0             13
# 4       1              0  3.35      2     2  590.0       5.0              1
#
#    admission
# 0          0
# 1          1
# 2          0
# 3          1
# 4          1

# %% [markdown]
# 13. create a heatmap to see the correlation and explain the conclusion

# %%
#13
import seaborn as sns
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), cmap='coolwarm',fmt = '.2f',
vmin=-1, vmax=1, annot=True)
plt.show()

#Conclusion
# GPA dan GMAT memiliki korelasi sebesar 0.58. Dimana GPA dan GMAT menjadi indikator akademik perfomance.
# Gender dan Admission memiliki korelasi sebesar 0.1. Gender menentukan untuk admission dari pendaftar.

# %% [markdown]
# **Challenge! Get Extra 10 Points**<br>
#
# get extra 10 points if you can help Lisa predict whether she will be accepted or not.
# Lisa is a local student, Lisa's gpa is the average of all applicants, during her undergraduate Lisa studied entrepreneurship, Lisa has an Asian race, gmat score 580, has worked from 2018 to 2020 as a finance.

# %%
#Challenge
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

x = data[['gender', 'international', 'gpa', 'major', 'race', 'gmat', 'work_exp', 'work_industry']]
y = data['admission']

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3)

# Create a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the classifier on the training data
clf.fit(x_train, y_train)

# Make predictions on the testing data
y_pred = clf.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of the model:", accuracy)

mean = data['gpa'].mean()

predicted_role_encoded = clf.predict([[0,0,mean,0,0,580,2,3]])
predicted_role = label_encoder.inverse_transform(predicted_role_encoded)

print(f"Predicted role for the character: {predicted_role[0]}")
# Out:
# Accuracy of the model: 0.7941888619854721
# Predicted role for the character: Deny
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
